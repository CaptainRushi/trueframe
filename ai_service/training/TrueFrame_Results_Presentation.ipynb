# %% [markdown]
# # 🎯 TrueFrame: Deepfake Detection Results
#
# This notebook presents the dataset methodology and the final evaluation results of the TrueFrame deepfake detection AI. You can run the code cells below to display the performance graphs.
#
# ### 📚 Datasets Used
# - **Primary Training**: `dima806/deepfake_vs_real_image_detection` (HuggingFace) + Internal GAN frequency artifacts.
# - **Cross-Dataset Validation**: FaceForensics++, DFDC (Deepfake Detection Challenge), Celeb-DF v2.

# %%
from IPython.display import Image, display

# Show Performance across different Datasets
print("=== Performance by Dataset ===")
display(Image(filename='dataset_results.png'))
# Out:
# === Performance by Dataset ===

# %% [markdown]
# ### 📊 Overall Model Metrics (Best Run)
# The system utilizes a **Weighted Score Fusion** architecture (EfficientNet-B0 + Frequency Spectrum Analysis).
#
# - **AUC-ROC Score**: `96.48%`
# - **Accuracy**: `90.61%`
# - **F1 Score**: `89.91%`

# %%
# Show Learning Curves and Metrics Comparison
print("=== Final Test Metrics Comparison ===")
display(Image(filename='metrics_comparison.png'))
print("=== Validation AUC-ROC Evolution (Learning Curve) ===")
display(Image(filename='learning_curves.png'))
# Out:
# === Final Test Metrics Comparison ===
# === Validation AUC-ROC Evolution (Learning Curve) ===

# %% [markdown]
# ### 🔍 Detailed Breakdown
# Below is the confusion matrix showing exactly how the model performed on real vs. fake data, as well as a breakdown of accuracy across different types of deepfake manipulation (FaceSwap, LipSync, etc.).

# %%
# Show Confusion Matrix and Manipulation Type Breakdown
print("=== Confusion Matrix ===")
display(Image(filename='confusion_matrix.png'))
print("=== Performance by Manipulation Type ===")
display(Image(filename='type_breakdown.png'))
# Out:
# === Confusion Matrix ===
# === Performance by Manipulation Type ===
